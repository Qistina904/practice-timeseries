# %%
#Week1
import pandas as pd
from matplotlib import pyplot as pyplot
# %matplotlib inline

# %%
##read first column as date  type
indiaclimate = pd.read_csv('DailyDelhiClimateTrain.csv', header = 0, parse_dates=[0])
indiaclimate.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
#check data type for date column 
indiaclimate['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#date column as index 
my_series = pd.read_csv('DailyDelhiClimateTrain.csv', header=0, parse_dates=[0], index_col=0)
my_series.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
#check number of column and row
my_series.shape
# Out:
# (1462, 4)

# %%
indiaclimate.shape
# Out:
# (1462, 5)

# %%
indiaclimate[(indiaclimate['date'] >= '2013-01-01') & (indiaclimate['date'] <= '2013-12-01')]
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure
# 0   2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1   2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2   2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3   2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4   2013-01-05   6.000000  86.833333    3.700000   1016.500000
# ..         ...        ...        ...         ...           ...
# 330 2013-11-27  19.125000  68.500000    2.787500   1014.750000
# 331 2013-11-28  18.625000  71.875000    1.850000   1017.750000
# 332 2013-11-29  17.750000  66.625000    4.862500   1016.875000
# 333 2013-11-30  17.875000  69.625000   11.812500   1015.875000
# 334 2013-12-01  18.000000  65.000000    1.585714   1016.142857
#
# [335 rows x 5 columns]

# %%
#summary stats
my_series.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
indiaclimate.describe()
# Out:
#                       date     meantemp     humidity   wind_speed  \
# count                 1462  1462.000000  1462.000000  1462.000000
# mean   2015-01-01 12:00:00    25.495521    60.771702     6.802209
# min    2013-01-01 00:00:00     6.000000    13.428571     0.000000
# 25%    2014-01-01 06:00:00    18.857143    50.375000     3.475000
# 50%    2015-01-01 12:00:00    27.714286    62.625000     6.221667
# 75%    2016-01-01 18:00:00    31.305804    72.218750     9.238235
# max    2017-01-01 00:00:00    38.714286   100.000000    42.220000
# std                    NaN     7.348103    16.769652     4.561602
#
#        meanpressure
# count   1462.000000
# mean    1011.104548
# min       -3.041667
# 25%     1001.580357
# 50%     1008.563492
# 75%     1014.944901
# max     7679.333333
# std      180.231668

# %%
#Feature Engineering 1
indiaclimate.head(7)
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000
# 5 2013-01-06   7.000000  82.800000    1.480000   1018.000000
# 6 2013-01-07   7.000000  78.600000    6.300000   1020.000000

# %%
myfeatures = indiaclimate.copy()

# %%
myfeatures['year']= indiaclimate['date'].dt.year
myfeatures['month'] =indiaclimate['date'].dt.month
myfeatures['day'] = indiaclimate['date'].dt.day

# %%
myfeatures.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month  day
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1    1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1    2
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1    3
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1    4
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1    5

# %%
#determine lag features. like K step ft + K, K = lag 2 
myfeatures['lag2'] = indiaclimate['wind_speed'].shift(2)

# %%
#1 year lag
myfeatures['lagyear'] = indiaclimate['wind_speed'].shift(365)
myfeatures.tail()
# Out:
#            date   meantemp    humidity  wind_speed  meanpressure  year  month  \
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217  2016     12
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762  2016     12
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762  2016     12
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000  2016     12
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000  2017      1
#
#       day      lag2   lagyear
# 1457   28  8.784211  7.412500
# 1458   29  8.335000  2.100000
# 1459   30  3.547826  2.087500
# 1460   31  6.000000  1.057143
# 1461    1  6.266667  2.087500

# %%
#calc mean with window size of 2
myfeatures['mean_roll']=indiaclimate['wind_speed'].rolling(window=2).mean()
myfeatures.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month  \
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1
#
#    day      lag2  lagyear  mean_roll
# 0    1       NaN      NaN        NaN
# 1    2       NaN      NaN   1.490000
# 2    3  0.000000      NaN   3.806667
# 3    4  2.980000      NaN   2.933333
# 4    5  4.633333      NaN   2.466667

# %%
myfeatures['max_roll']=indiaclimate['wind_speed'].rolling(window=3).max()
myfeatures.head(10)
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month  \
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1
# 5 2013-01-06   7.000000  82.800000    1.480000   1018.000000  2013      1
# 6 2013-01-07   7.000000  78.600000    6.300000   1020.000000  2013      1
# 7 2013-01-08   8.857143  63.714286    7.142857   1018.714286  2013      1
# 8 2013-01-09  14.000000  51.250000   12.500000   1017.000000  2013      1
# 9 2013-01-10  11.000000  62.000000    7.400000   1015.666667  2013      1
#
#    day      lag2  lagyear  mean_roll   max_roll
# 0    1       NaN      NaN        NaN        NaN
# 1    2       NaN      NaN   1.490000        NaN
# ...

# %%
#fo entire column, max value 
myfeatures['max_expand'] =indiaclimate['wind_speed'].expanding().max()
myfeatures.head(10)
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month  \
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1
# 5 2013-01-06   7.000000  82.800000    1.480000   1018.000000  2013      1
# 6 2013-01-07   7.000000  78.600000    6.300000   1020.000000  2013      1
# 7 2013-01-08   8.857143  63.714286    7.142857   1018.714286  2013      1
# 8 2013-01-09  14.000000  51.250000   12.500000   1017.000000  2013      1
# 9 2013-01-10  11.000000  62.000000    7.400000   1015.666667  2013      1
#
#    day      lag2  lagyear  mean_roll   max_roll  max_expand
# 0    1       NaN      NaN        NaN        NaN    0.000000
# ...

# %%
##create viz
newdata_df = indiaclimate.copy()

# %%
newdata_df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
newdata_df['wind_speed'].plot()
# Out:
# <Axes: >

# %%
newdata_df.index =newdata_df['date']

# %%
newdata_df['wind_speed'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
newdata_df2 = newdata_df[(newdata_df['date'] >= '2013-01-01') & (newdata_df['date'] <= '2013-01-10')].copy()
newdata_df2
# Out:
#                  date   meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05 2013-01-05   6.000000  86.833333    3.700000   1016.500000
# 2013-01-06 2013-01-06   7.000000  82.800000    1.480000   1018.000000
# 2013-01-07 2013-01-07   7.000000  78.600000    6.300000   1020.000000
# 2013-01-08 2013-01-08   8.857143  63.714286    7.142857   1018.714286
# 2013-01-09 2013-01-09  14.000000  51.250000   12.500000   1017.000000
# 2013-01-10 2013-01-10  11.000000  62.000000    7.400000   1015.666667

# %%
newdata_df2['wind_speed'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
## regression line / trend line / tendency your dataset
##incr / dec, constant across variance, those thing we want to know
import seaborn as sns

# %%
#creating linear regression trend 
sns.regplot(x=indiaclimate.index.values, y = indiaclimate['wind_speed'])
# order = 2 means, quadratic trend line
sns.regplot(x=indiaclimate.index.values, y = indiaclimate['wind_speed'], order=2)
# Out:
# <Axes: ylabel='wind_speed'>

# %%
#removing seasonality
newdata_df['wind_speed'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
newdata_df
# Out:
#                  date   meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...        ...         ...         ...           ...
# 2016-12-28 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
newdata_df['year'] = newdata_df['date'].dt.year
newdata_df
# Out:
#                  date   meantemp    humidity  wind_speed  meanpressure  year
# date
# 2013-01-01 2013-01-01  10.000000   84.500000    0.000000   1015.666667  2013
# 2013-01-02 2013-01-02   7.400000   92.000000    2.980000   1017.800000  2013
# 2013-01-03 2013-01-03   7.166667   87.000000    4.633333   1018.666667  2013
# 2013-01-04 2013-01-04   8.666667   71.333333    1.233333   1017.166667  2013
# 2013-01-05 2013-01-05   6.000000   86.833333    3.700000   1016.500000  2013
# ...               ...        ...         ...         ...           ...   ...
# 2016-12-28 2016-12-28  17.217391   68.043478    3.547826   1015.565217  2016
# 2016-12-29 2016-12-29  15.238095   87.857143    6.000000   1016.904762  2016
# 2016-12-30 2016-12-30  14.095238   89.666667    6.266667   1017.904762  2016
# 2016-12-31 2016-12-31  15.052632   87.000000    7.325000   1016.100000  2016
# 2017-01-01 2017-01-01  10.000000  100.000000    0.000000   1016.000000  2017
#
# [1462 rows x 6 columns]

# %%
#get the mean for each year by groupby the year.
newdata_df.groupby('year')['wind_speed'].mean()
# Out:
# year
# 2013    6.827253
# 2014    6.756148
# 2015    6.480603
# 2016    7.162480
# 2017    0.000000
# Name: wind_speed, dtype: float64

# %%
#average wind speed for each year 
newdata_df.groupby('year')['wind_speed'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
#shifted by 1 so it created lag 1
newdata_df['lag 1'] =newdata_df['wind_speed'].shift(1)
newdata_df.head()
# Out:
#                  date   meantemp   humidity  wind_speed  meanpressure  year  \
# date
# 2013-01-01 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013
# 2013-01-02 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013
# 2013-01-03 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013
# 2013-01-04 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013
# 2013-01-05 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013
#
#                lag 1
# date
# 2013-01-01       NaN
# 2013-01-02  0.000000
# 2013-01-03  2.980000
# 2013-01-04  4.633333
# 2013-01-05  1.233333

# %%
sns.scatterplot(x=newdata_df['lag 1'], y=newdata_df['wind_speed'])
# Out:
# <Axes: xlabel='lag 1', ylabel='wind_speed'>

# %%
from pandas.plotting import lag_plot

# %%
#identify pattern or seasonality in my data by lag 1
lag_plot(newdata_df['wind_speed'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from pandas.plotting import autocorrelation_plot

# %%
#plot for autocorrelation
autocorrelation_plot(newdata_df['wind_speed'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
#power transformation
#some need some no 
#when we plotted, we see non linear trends, like exponential trend, then w take log values, then we take log values for forecast
#only some model requires power transformation.
